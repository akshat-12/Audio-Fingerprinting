# %%
import os
import librosa
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage  import generate_binary_structure , binary_erosion , iterate_structure
from scipy.ndimage import maximum_filter
from scipy.signal import find_peaks
from sklearn.manifold import LocallyLinearEmbedding
import librosa

# %%
pip install fastdtw
# Out:
# Collecting fastdtw
#   Downloading fastdtw-0.3.4.tar.gz (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 757.5 kB/s eta 0:00:00m eta 0:00:010:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/akshat/anaconda3/lib/python3.10/site-packages (from fastdtw) (1.23.5)
# Building wheels for collected packages: fastdtw
#   Building wheel for fastdtw (setup.py) ... done
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-py3-none-any.whl size=3564 sha256=1c61eb7c8988779a425d6ba29b364cf449f9277e61ae3dc137171cd568e67660
#   Stored in directory: /home/akshat/.cache/pip/wheels/b2/b2/20/c0960e8ee3ceaf158c43f28eea50357113dfe2f3106da9fdb1
# Successfully built fastdtw
# Installing collected packages: fastdtw
# Successfully installed fastdtw-0.3.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.spatial.distance import euclidean
from fastdtw import fastdtw

# %%
def load_song(song, sr):
    scale , sr = librosa.load(song,sr=8000)
    pre_emphasized_signal = librosa.effects.preemphasis(scale, coef=0.97)
    hop_length = int(sr * 0.09)  # 10 ms hop
    win_length = int(sr * 0.1)   # 100 ms frame
    spectrogram = librosa.stft(pre_emphasized_signal, n_fft=win_length, hop_length=hop_length)
    spectrogram = np.abs(spectrogram)
#     plot_spectrogram(librosa.amplitude_to_db(spectrogram, ref=np.max), sr, hop_length)
    return spectrogram

# %%
def plot_spectrogram(Y, sr, hop_length, y_axis="linear"):
    plt.figure(figsize=(25, 10))
    librosa.display.specshow(Y, 
                             sr=sr, 
                             hop_length=hop_length, 
                             x_axis="time", 
                             y_axis=y_axis)
    plt.colorbar(format="%+2.f")

# %%
def mel_spectrogram_func(spectrogram):
    sr = 8000
    hop_length = int(sr * 0.09)  # 10 ms hop
    win_length = int(sr * 0.1)   # 100 ms frame
    mel_spectrogram = librosa.feature.melspectrogram(S=spectrogram, sr=sr, n_mels=18,n_fft=win_length, hop_length=hop_length)
    mel_spectrogram = np.abs(mel_spectrogram)
#     plot_spectrogram(librosa.amplitude_to_db(mel_spectrogram, ref=np.max), sr, hop_length, y_axis="mel")
    return mel_spectrogram

# %%
def get_peaks(mel_spectrogram):
    j = 0
    twod_peaks = []
    for frame in mel_spectrogram.T:
        peaks, _ = find_peaks(frame)
        #Get the bigggest peak
        maxPeak = -float('inf')    
        maxPeakIndex = -1
        for peak in peaks :
            if peak >= 2 and frame[peak] > maxPeak and peak < 16:
                maxPeak = frame[peak]
                maxPeakIndex = peak
        if maxPeakIndex != -1 :
            twod_peaks.append((maxPeakIndex,j))
        j += 1

    twod_peaks.sort(key=lambda x: mel_spectrogram[x[0]][x[1]], reverse = True)
#     n_peaks = 100
#     peaks = []
#     for x in range(n_peaks):
#         peaks.append(twod_peaks[x])
    peaks = twod_peaks
    return peaks

# %%
def show_peaks(peaks):
    print(peaks)

    #draw a scatter graph of peaks
    plt.figure(figsize=(25, 10))
    plt.scatter([x[1] for x in peaks], [x[0] for x in peaks])
    plt.show()
    print(len(peaks))

# %%
def max_amplitude_each_frame(mel_spectrogram):
    # drwaw a graph of maximum ampliuide of each frame
    plt.figure(figsize=(25, 10))
    plt.plot([np.max(frame) for frame in mel_spectrogram.T])
    plt.show()

# %%
def generate_eh(peaks):
    eh = []
    for (i,j) in peaks  :
        x = j - 9
        e = []
        for x in  range(j-9,j-2,2) :
            e.append(sum(mel_spectrogram[i][x:x+3]))

        for x in range(j+1,j+8,2):
            e.append(sum(mel_spectrogram[i][x:x+3]))
        eh.append(e)
    eh = np.array(eh)
    return eh

# %%
def generate_ev(peaks):
    ev = []
    for (i,j) in peaks  :
        if j + 2 >= mel_spectrogram.shape[1] :
            continue
        e = []
        e.append(sum(mel_spectrogram[i+2][j-1:j+2]))
        e.append(sum(mel_spectrogram[i+1][j-1:j+2]))
        e.append(sum(mel_spectrogram[i-1][j-1:j+2]))
        e.append(sum(mel_spectrogram[i-2][j-1:j+2]))
        ev.append(e)
    ev = np.array(ev)
    return ev

# %%
def generate_ec(peaks):
    ec = []
    for (i, j) in peaks:
        e = []
        x = sum(mel_spectrogram[i+1][j-2:j+1])
        x += sum(mel_spectrogram[i][j-2:j+1])
        e.append(x)
        x = sum(mel_spectrogram[i+1][j:j+3])
        x += sum(mel_spectrogram[i][j:j+3])
        e.append(x)
        x = sum(mel_spectrogram[i][j:j+3])
        x += sum(mel_spectrogram[i-1][j:j+3])
        e.append(x)
        x = sum(mel_spectrogram[i][j-2:j+1])
        x += sum(mel_spectrogram[i-1][j-2:j+1])
        e.append(x)
        ec.append(e)
    ec = np.array(ec)
    return ec

# %%
def generate_em(peaks):
    em = []
    for (i,j) in peaks :
        e = []
        x = sum(mel_spectrogram[i+2][j-9:j-5])
        x += sum(mel_spectrogram[i+1][j-9:j-5])
        e.append(x)
        x = sum(mel_spectrogram[i+2][j-5:j-1])
        x += sum(mel_spectrogram[i+1][j-5:j-1])
        e.append(x)
        x = sum(mel_spectrogram[i-1][j-9:j-5])
        x += sum(mel_spectrogram[i-2][j-9:j-5])
        e.append(x)
        x = sum(mel_spectrogram[i-1][j-5:j-1])
        x += sum(mel_spectrogram[i-2][j-5:j-1])
        e.append(x)
        x = sum(mel_spectrogram[i+2][j+2:j+6])
        x += sum(mel_spectrogram[i+1][j+2:j+6])
        e.append(x)
        x = sum(mel_spectrogram[i+2][j+6:j+10])
        x += sum(mel_spectrogram[i+1][j+6:j+10])
        e.append(x)
        x = sum(mel_spectrogram[i-1][j+2:j+6])
        x += sum(mel_spectrogram[i-2][j+2:j+6])
        e.append(x)
        x = sum(mel_spectrogram[i-1][j+6:j+10])
        x += sum(mel_spectrogram[i-2][j+6:j+10])
        e.append(x)
        em.append(e)
    em = np.array(em)
    return em

# %%
def lle(e, n_components, n_neighbors):
    lle = LocallyLinearEmbedding(n_components=n_components, n_neighbors=n_neighbors)
    e_transformed = lle.fit_transform(e)
    return e_transformed

# %%
def generate_fingerprint(eh, ev, ec, em):
    fingerprint = []
    for i in range(1, eh.shape[0]):
        for j in range(1, eh.shape[1]):
            if eh[i][j] - eh[i][j-1] > 0:
                fingerprint.append(1)
            else:
                fingerprint.append(0)
    for i in range(1, ev.shape[0]):
        for j in range(1, ev.shape[1]):
            if ev[i][j] - ev[i][j-1] > 0:
                fingerprint.append(1)
            else:
                fingerprint.append(0)
    for i in range(1, ec.shape[0]):
        for j in range(1, ec.shape[1]):
            if ec[i][j] - ec[i][j-1] > 0:
                fingerprint.append(1)
            else:
                fingerprint.append(0)
    for i in range(1, em.shape[0]):
        for j in range(1, em.shape[1]):
            if em[i][j] - em[i][j-1] > 0:
                fingerprint.append(1)
            else:
                fingerprint.append(0)
    fingerprint = np.array(fingerprint)
    return fingerprint

# %%
def dynamic_time_warping(s, t):
    n, m = len(s), len(t)
    D = np.zeros((n+1, m+1))
    D[:, 0] = np.inf
    D[0, :] = np.inf
    D[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = abs(s[i-1] - t[j-1])
            D[i, j] = cost + min(D[i-1, j], D[i, j-1], D[i-1, j-1])
    return D[-1, -1]

# %%
os.chdir('signals/dataset/genres')
# os.chdir('..')

# %%
os.getcwd()
# Out:
# '/home/akshat/signals/dataset/genres'

# %%
fingerprints = {}

# %%
for filename in os.listdir(os.getcwd()):
    f = os.path.join(os.getcwd(), filename)
    if os.path.isdir(f):
        os.chdir(f)
        for file in os.listdir(os.getcwd()):
            file1 = os.path.join(os.getcwd(), file)
            if os.path.isfile(file1):
                print(file1)
                spectrogram = load_song(file1, 8000)
                mel_spectrogram = mel_spectrogram_func(spectrogram)
                peaks = get_peaks(mel_spectrogram)
#                 show_peaks(peaks)
#                 max_amplitude_each_frame(mel_spectrogram)
                eh = generate_eh(peaks)
                ev = generate_ev(peaks)
                ec = generate_ec(peaks)
                em = generate_em(peaks)
#                 eh_t = lle(eh, 6, 3)
#                 ev_t = lle(ev, 3, 3)
#                 ec_t = lle(ec, 3, 3)
#                 em_t = lle(em, 6, 3)
                fingerprint = generate_fingerprint(eh, ev, ec, em)
                fingerprints[file] = fingerprint
        os.chdir('..')
# Out:
# /home/akshat/signals/dataset/genres/jazz/jazz.00056.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00024.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00046.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00048.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00043.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00028.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00073.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00055.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00054.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00064.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00036.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00021.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00001.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00006.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00057.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00084.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00069.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00016.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00059.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00075.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00094.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00062.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00027.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00096.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00070.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00086.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00002.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00077.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00097.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00033.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00005.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00095.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00029.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00068.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00017.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00032.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00007.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00034.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00042.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00087.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00035.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00091.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00061.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00083.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00072.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00049.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00065.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00079.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00025.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00071.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00052.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00080.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00053.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00089.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00090.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00004.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00078.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00041.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00063.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00058.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00018.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00026.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00003.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00013.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00010.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00038.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00099.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00051.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00092.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00015.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00000.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00014.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00066.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00074.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00008.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00019.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00085.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00009.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00039.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00037.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00081.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00030.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00067.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00040.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00098.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00022.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00045.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00044.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00031.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00012.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00050.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00020.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00088.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00047.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00093.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00060.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00076.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00082.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00011.au
# /home/akshat/signals/dataset/genres/jazz/jazz.00023.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00021.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00086.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00043.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00052.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00028.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00094.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00073.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00010.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00090.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00012.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00037.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00034.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00072.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00018.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00041.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00039.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00015.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00061.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00032.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00000.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00025.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00027.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00054.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00065.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00016.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00033.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00038.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00003.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00099.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00092.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00029.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00060.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00064.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00083.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00047.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00063.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00096.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00005.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00031.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00095.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00088.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00062.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00071.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00056.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00017.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00066.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00079.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00023.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00007.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00035.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00068.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00081.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00098.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00009.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00006.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00042.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00002.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00087.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00053.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00055.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00019.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00080.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00040.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00076.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00084.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00051.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00067.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00001.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00059.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00026.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00049.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00036.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00022.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00074.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00097.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00044.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00078.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00085.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00069.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00077.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00045.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00089.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00050.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00020.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00011.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00082.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00008.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00046.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00048.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00013.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00091.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00075.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00014.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00093.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00070.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00004.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00030.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00024.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00057.au
# /home/akshat/signals/dataset/genres/hiphop/hiphop.00058.au
# /home/akshat/signals/dataset/genres/pop/pop.00066.au
# /home/akshat/signals/dataset/genres/pop/pop.00013.au
# /home/akshat/signals/dataset/genres/pop/pop.00075.au
# /home/akshat/signals/dataset/genres/pop/pop.00098.au
# /home/akshat/signals/dataset/genres/pop/pop.00059.au
# /home/akshat/signals/dataset/genres/pop/pop.00087.au
# /home/akshat/signals/dataset/genres/pop/pop.00063.au
# /home/akshat/signals/dataset/genres/pop/pop.00070.au
# /home/akshat/signals/dataset/genres/pop/pop.00078.au
# /home/akshat/signals/dataset/genres/pop/pop.00001.au
# /home/akshat/signals/dataset/genres/pop/pop.00047.au
# /home/akshat/signals/dataset/genres/pop/pop.00004.au
# /home/akshat/signals/dataset/genres/pop/pop.00081.au
# /home/akshat/signals/dataset/genres/pop/pop.00039.au
# /home/akshat/signals/dataset/genres/pop/pop.00051.au
# /home/akshat/signals/dataset/genres/pop/pop.00085.au
# /home/akshat/signals/dataset/genres/pop/pop.00076.au
# /home/akshat/signals/dataset/genres/pop/pop.00049.au
# /home/akshat/signals/dataset/genres/pop/pop.00028.au
# /home/akshat/signals/dataset/genres/pop/pop.00015.au
# /home/akshat/signals/dataset/genres/pop/pop.00024.au
# /home/akshat/signals/dataset/genres/pop/pop.00017.au
# /home/akshat/signals/dataset/genres/pop/pop.00011.au
# /home/akshat/signals/dataset/genres/pop/pop.00036.au
# /home/akshat/signals/dataset/genres/pop/pop.00021.au
# /home/akshat/signals/dataset/genres/pop/pop.00002.au
# /home/akshat/signals/dataset/genres/pop/pop.00029.au
# /home/akshat/signals/dataset/genres/pop/pop.00030.au
# /home/akshat/signals/dataset/genres/pop/pop.00006.au
# /home/akshat/signals/dataset/genres/pop/pop.00043.au
# /home/akshat/signals/dataset/genres/pop/pop.00086.au
# /home/akshat/signals/dataset/genres/pop/pop.00055.au
# /home/akshat/signals/dataset/genres/pop/pop.00077.au
# /home/akshat/signals/dataset/genres/pop/pop.00090.au
# /home/akshat/signals/dataset/genres/pop/pop.00067.au
# /home/akshat/signals/dataset/genres/pop/pop.00034.au
# /home/akshat/signals/dataset/genres/pop/pop.00095.au
# /home/akshat/signals/dataset/genres/pop/pop.00041.au
# /home/akshat/signals/dataset/genres/pop/pop.00093.au
# /home/akshat/signals/dataset/genres/pop/pop.00092.au
# /home/akshat/signals/dataset/genres/pop/pop.00005.au
# /home/akshat/signals/dataset/genres/pop/pop.00089.au
# /home/akshat/signals/dataset/genres/pop/pop.00007.au
# /home/akshat/signals/dataset/genres/pop/pop.00073.au
# /home/akshat/signals/dataset/genres/pop/pop.00072.au
# /home/akshat/signals/dataset/genres/pop/pop.00061.au
# /home/akshat/signals/dataset/genres/pop/pop.00079.au
# /home/akshat/signals/dataset/genres/pop/pop.00000.au
# /home/akshat/signals/dataset/genres/pop/pop.00012.au
# /home/akshat/signals/dataset/genres/pop/pop.00056.au
# /home/akshat/signals/dataset/genres/pop/pop.00068.au
# /home/akshat/signals/dataset/genres/pop/pop.00091.au
# /home/akshat/signals/dataset/genres/pop/pop.00058.au
# /home/akshat/signals/dataset/genres/pop/pop.00031.au
# /home/akshat/signals/dataset/genres/pop/pop.00026.au
# /home/akshat/signals/dataset/genres/pop/pop.00020.au
# /home/akshat/signals/dataset/genres/pop/pop.00032.au
# /home/akshat/signals/dataset/genres/pop/pop.00014.au
# /home/akshat/signals/dataset/genres/pop/pop.00023.au
# /home/akshat/signals/dataset/genres/pop/pop.00046.au
# /home/akshat/signals/dataset/genres/pop/pop.00097.au
# /home/akshat/signals/dataset/genres/pop/pop.00048.au
# /home/akshat/signals/dataset/genres/pop/pop.00062.au
# /home/akshat/signals/dataset/genres/pop/pop.00022.au
# /home/akshat/signals/dataset/genres/pop/pop.00065.au
# /home/akshat/signals/dataset/genres/pop/pop.00088.au
# /home/akshat/signals/dataset/genres/pop/pop.00018.au
# /home/akshat/signals/dataset/genres/pop/pop.00042.au
# /home/akshat/signals/dataset/genres/pop/pop.00064.au
# /home/akshat/signals/dataset/genres/pop/pop.00003.au
# /home/akshat/signals/dataset/genres/pop/pop.00038.au
# /home/akshat/signals/dataset/genres/pop/pop.00044.au
# /home/akshat/signals/dataset/genres/pop/pop.00083.au
# /home/akshat/signals/dataset/genres/pop/pop.00027.au
# /home/akshat/signals/dataset/genres/pop/pop.00045.au
# /home/akshat/signals/dataset/genres/pop/pop.00052.au
# /home/akshat/signals/dataset/genres/pop/pop.00009.au
# /home/akshat/signals/dataset/genres/pop/pop.00099.au
# /home/akshat/signals/dataset/genres/pop/pop.00053.au
# /home/akshat/signals/dataset/genres/pop/pop.00082.au
# /home/akshat/signals/dataset/genres/pop/pop.00050.au
# /home/akshat/signals/dataset/genres/pop/pop.00096.au
# /home/akshat/signals/dataset/genres/pop/pop.00084.au
# /home/akshat/signals/dataset/genres/pop/pop.00008.au
# /home/akshat/signals/dataset/genres/pop/pop.00016.au
# /home/akshat/signals/dataset/genres/pop/pop.00094.au
# /home/akshat/signals/dataset/genres/pop/pop.00025.au
# /home/akshat/signals/dataset/genres/pop/pop.00057.au
# /home/akshat/signals/dataset/genres/pop/pop.00040.au
# /home/akshat/signals/dataset/genres/pop/pop.00035.au
# /home/akshat/signals/dataset/genres/pop/pop.00019.au
# /home/akshat/signals/dataset/genres/pop/pop.00074.au
# /home/akshat/signals/dataset/genres/pop/pop.00069.au
# /home/akshat/signals/dataset/genres/pop/pop.00037.au
# /home/akshat/signals/dataset/genres/pop/pop.00033.au
# /home/akshat/signals/dataset/genres/pop/pop.00010.au
# /home/akshat/signals/dataset/genres/pop/pop.00080.au
# /home/akshat/signals/dataset/genres/pop/pop.00071.au
# /home/akshat/signals/dataset/genres/pop/pop.00054.au
# /home/akshat/signals/dataset/genres/pop/pop.00060.au
# /home/akshat/signals/dataset/genres/metal/metal.00039.au
# /home/akshat/signals/dataset/genres/metal/metal.00001.au
# /home/akshat/signals/dataset/genres/metal/metal.00040.au
# /home/akshat/signals/dataset/genres/metal/metal.00006.au
# /home/akshat/signals/dataset/genres/metal/metal.00061.au
# /home/akshat/signals/dataset/genres/metal/metal.00090.au
# /home/akshat/signals/dataset/genres/metal/metal.00019.au
# /home/akshat/signals/dataset/genres/metal/metal.00012.au
# /home/akshat/signals/dataset/genres/metal/metal.00020.au
# /home/akshat/signals/dataset/genres/metal/metal.00028.au
# /home/akshat/signals/dataset/genres/metal/metal.00011.au
# /home/akshat/signals/dataset/genres/metal/metal.00078.au
# /home/akshat/signals/dataset/genres/metal/metal.00077.au
# /home/akshat/signals/dataset/genres/metal/metal.00085.au
# /home/akshat/signals/dataset/genres/metal/metal.00070.au
# /home/akshat/signals/dataset/genres/metal/metal.00042.au
# /home/akshat/signals/dataset/genres/metal/metal.00056.au
# /home/akshat/signals/dataset/genres/metal/metal.00008.au
# /home/akshat/signals/dataset/genres/metal/metal.00044.au
# /home/akshat/signals/dataset/genres/metal/metal.00010.au
# /home/akshat/signals/dataset/genres/metal/metal.00063.au
# /home/akshat/signals/dataset/genres/metal/metal.00015.au
# /home/akshat/signals/dataset/genres/metal/metal.00068.au
# /home/akshat/signals/dataset/genres/metal/metal.00064.au
# /home/akshat/signals/dataset/genres/metal/metal.00021.au
# /home/akshat/signals/dataset/genres/metal/metal.00098.au
# /home/akshat/signals/dataset/genres/metal/metal.00050.au
# /home/akshat/signals/dataset/genres/metal/metal.00016.au
# /home/akshat/signals/dataset/genres/metal/metal.00072.au
# /home/akshat/signals/dataset/genres/metal/metal.00060.au
# /home/akshat/signals/dataset/genres/metal/metal.00005.au
# /home/akshat/signals/dataset/genres/metal/metal.00079.au
# /home/akshat/signals/dataset/genres/metal/metal.00041.au
# /home/akshat/signals/dataset/genres/metal/metal.00025.au
# /home/akshat/signals/dataset/genres/metal/metal.00014.au
# /home/akshat/signals/dataset/genres/metal/metal.00055.au
# /home/akshat/signals/dataset/genres/metal/metal.00080.au
# /home/akshat/signals/dataset/genres/metal/metal.00066.au
# /home/akshat/signals/dataset/genres/metal/metal.00097.au
# /home/akshat/signals/dataset/genres/metal/metal.00096.au
# /home/akshat/signals/dataset/genres/metal/metal.00073.au
# /home/akshat/signals/dataset/genres/metal/metal.00026.au
# /home/akshat/signals/dataset/genres/metal/metal.00022.au
# /home/akshat/signals/dataset/genres/metal/metal.00075.au
# /home/akshat/signals/dataset/genres/metal/metal.00043.au
# /home/akshat/signals/dataset/genres/metal/metal.00095.au
# /home/akshat/signals/dataset/genres/metal/metal.00092.au
# /home/akshat/signals/dataset/genres/metal/metal.00051.au
# /home/akshat/signals/dataset/genres/metal/metal.00023.au
# /home/akshat/signals/dataset/genres/metal/metal.00069.au
# /home/akshat/signals/dataset/genres/metal/metal.00031.au
# /home/akshat/signals/dataset/genres/metal/metal.00074.au
# /home/akshat/signals/dataset/genres/metal/metal.00053.au
# /home/akshat/signals/dataset/genres/metal/metal.00030.au
# /home/akshat/signals/dataset/genres/metal/metal.00002.au
# /home/akshat/signals/dataset/genres/metal/metal.00037.au
# /home/akshat/signals/dataset/genres/metal/metal.00062.au
# /home/akshat/signals/dataset/genres/metal/metal.00054.au
# /home/akshat/signals/dataset/genres/metal/metal.00035.au
# /home/akshat/signals/dataset/genres/metal/metal.00081.au
# /home/akshat/signals/dataset/genres/metal/metal.00009.au
# /home/akshat/signals/dataset/genres/metal/metal.00099.au
# /home/akshat/signals/dataset/genres/metal/metal.00029.au
# /home/akshat/signals/dataset/genres/metal/metal.00024.au
# /home/akshat/signals/dataset/genres/metal/metal.00087.au
# /home/akshat/signals/dataset/genres/metal/metal.00067.au
# /home/akshat/signals/dataset/genres/metal/metal.00032.au
# /home/akshat/signals/dataset/genres/metal/metal.00071.au
# /home/akshat/signals/dataset/genres/metal/metal.00007.au
# /home/akshat/signals/dataset/genres/metal/metal.00034.au
# /home/akshat/signals/dataset/genres/metal/metal.00045.au
# /home/akshat/signals/dataset/genres/metal/metal.00076.au
# /home/akshat/signals/dataset/genres/metal/metal.00057.au
# /home/akshat/signals/dataset/genres/metal/metal.00013.au
# /home/akshat/signals/dataset/genres/metal/metal.00004.au
# /home/akshat/signals/dataset/genres/metal/metal.00089.au
# /home/akshat/signals/dataset/genres/metal/metal.00046.au
# /home/akshat/signals/dataset/genres/metal/metal.00036.au
# /home/akshat/signals/dataset/genres/metal/metal.00065.au
# /home/akshat/signals/dataset/genres/metal/metal.00088.au
# /home/akshat/signals/dataset/genres/metal/metal.00059.au
# /home/akshat/signals/dataset/genres/metal/metal.00027.au
# /home/akshat/signals/dataset/genres/metal/metal.00000.au
# /home/akshat/signals/dataset/genres/metal/metal.00018.au
# /home/akshat/signals/dataset/genres/metal/metal.00017.au
# /home/akshat/signals/dataset/genres/metal/metal.00086.au
# /home/akshat/signals/dataset/genres/metal/metal.00052.au
# /home/akshat/signals/dataset/genres/metal/metal.00038.au
# /home/akshat/signals/dataset/genres/metal/metal.00091.au
# /home/akshat/signals/dataset/genres/metal/metal.00094.au
# /home/akshat/signals/dataset/genres/metal/metal.00082.au
# /home/akshat/signals/dataset/genres/metal/metal.00084.au
# /home/akshat/signals/dataset/genres/metal/metal.00048.au
# /home/akshat/signals/dataset/genres/metal/metal.00049.au
# /home/akshat/signals/dataset/genres/metal/metal.00003.au
# /home/akshat/signals/dataset/genres/metal/metal.00047.au
# /home/akshat/signals/dataset/genres/metal/metal.00033.au
# /home/akshat/signals/dataset/genres/metal/metal.00093.au
# /home/akshat/signals/dataset/genres/metal/metal.00083.au
# /home/akshat/signals/dataset/genres/metal/metal.00058.au
# /home/akshat/signals/dataset/genres/blues/blues.00004.au
# /home/akshat/signals/dataset/genres/blues/blues.00053.au
# /home/akshat/signals/dataset/genres/blues/blues.00051.au
# /home/akshat/signals/dataset/genres/blues/blues.00033.au
# /home/akshat/signals/dataset/genres/blues/blues.00039.au
# /home/akshat/signals/dataset/genres/blues/blues.00090.au
# /home/akshat/signals/dataset/genres/blues/blues.00066.au
# /home/akshat/signals/dataset/genres/blues/blues.00055.au
# /home/akshat/signals/dataset/genres/blues/blues.00046.au
# /home/akshat/signals/dataset/genres/blues/blues.00084.au
# /home/akshat/signals/dataset/genres/blues/blues.00050.au
# /home/akshat/signals/dataset/genres/blues/blues.00037.au
# /home/akshat/signals/dataset/genres/blues/blues.00068.au
# /home/akshat/signals/dataset/genres/blues/blues.00040.au
# /home/akshat/signals/dataset/genres/blues/blues.00079.au
# /home/akshat/signals/dataset/genres/blues/blues.00048.au
# /home/akshat/signals/dataset/genres/blues/blues.00020.au
# /home/akshat/signals/dataset/genres/blues/blues.00026.au
# /home/akshat/signals/dataset/genres/blues/blues.00093.au
# /home/akshat/signals/dataset/genres/blues/blues.00005.au
# /home/akshat/signals/dataset/genres/blues/blues.00001.au
# /home/akshat/signals/dataset/genres/blues/blues.00002.au
# /home/akshat/signals/dataset/genres/blues/blues.00074.au
# /home/akshat/signals/dataset/genres/blues/blues.00065.au
# /home/akshat/signals/dataset/genres/blues/blues.00042.au
# /home/akshat/signals/dataset/genres/blues/blues.00080.au
# /home/akshat/signals/dataset/genres/blues/blues.00086.au
# /home/akshat/signals/dataset/genres/blues/blues.00043.au
# /home/akshat/signals/dataset/genres/blues/blues.00082.au
# /home/akshat/signals/dataset/genres/blues/blues.00031.au
# /home/akshat/signals/dataset/genres/blues/blues.00096.au
# /home/akshat/signals/dataset/genres/blues/blues.00027.au
# /home/akshat/signals/dataset/genres/blues/blues.00036.au
# /home/akshat/signals/dataset/genres/blues/blues.00028.au
# /home/akshat/signals/dataset/genres/blues/blues.00085.au
# /home/akshat/signals/dataset/genres/blues/blues.00073.au
# /home/akshat/signals/dataset/genres/blues/blues.00049.au
# /home/akshat/signals/dataset/genres/blues/blues.00075.au
# /home/akshat/signals/dataset/genres/blues/blues.00054.au
# /home/akshat/signals/dataset/genres/blues/blues.00057.au
# /home/akshat/signals/dataset/genres/blues/blues.00097.au
# /home/akshat/signals/dataset/genres/blues/blues.00069.au
# /home/akshat/signals/dataset/genres/blues/blues.00058.au
# /home/akshat/signals/dataset/genres/blues/blues.00003.au
# /home/akshat/signals/dataset/genres/blues/blues.00009.au
# /home/akshat/signals/dataset/genres/blues/blues.00022.au
# /home/akshat/signals/dataset/genres/blues/blues.00089.au
# /home/akshat/signals/dataset/genres/blues/blues.00099.au
# /home/akshat/signals/dataset/genres/blues/blues.00047.au
# /home/akshat/signals/dataset/genres/blues/blues.00030.au
# /home/akshat/signals/dataset/genres/blues/blues.00041.au
# /home/akshat/signals/dataset/genres/blues/blues.00092.au
# /home/akshat/signals/dataset/genres/blues/blues.00056.au
# /home/akshat/signals/dataset/genres/blues/blues.00071.au
# /home/akshat/signals/dataset/genres/blues/blues.00062.au
# /home/akshat/signals/dataset/genres/blues/blues.00063.au
# /home/akshat/signals/dataset/genres/blues/blues.00012.au
# /home/akshat/signals/dataset/genres/blues/blues.00094.au
# /home/akshat/signals/dataset/genres/blues/blues.00015.au
# /home/akshat/signals/dataset/genres/blues/blues.00076.au
# /home/akshat/signals/dataset/genres/blues/blues.00044.au
# /home/akshat/signals/dataset/genres/blues/blues.00059.au
# /home/akshat/signals/dataset/genres/blues/blues.00008.au
# /home/akshat/signals/dataset/genres/blues/blues.00006.au
# /home/akshat/signals/dataset/genres/blues/blues.00045.au
# /home/akshat/signals/dataset/genres/blues/blues.00060.au
# /home/akshat/signals/dataset/genres/blues/blues.00029.au
# /home/akshat/signals/dataset/genres/blues/blues.00032.au
# /home/akshat/signals/dataset/genres/blues/blues.00007.au
# /home/akshat/signals/dataset/genres/blues/blues.00077.au
# /home/akshat/signals/dataset/genres/blues/blues.00018.au
# /home/akshat/signals/dataset/genres/blues/blues.00067.au
# /home/akshat/signals/dataset/genres/blues/blues.00038.au
# /home/akshat/signals/dataset/genres/blues/blues.00095.au
# /home/akshat/signals/dataset/genres/blues/blues.00019.au
# /home/akshat/signals/dataset/genres/blues/blues.00070.au
# /home/akshat/signals/dataset/genres/blues/blues.00072.au
# /home/akshat/signals/dataset/genres/blues/blues.00024.au
# /home/akshat/signals/dataset/genres/blues/blues.00025.au
# /home/akshat/signals/dataset/genres/blues/blues.00023.au
# /home/akshat/signals/dataset/genres/blues/blues.00011.au
# /home/akshat/signals/dataset/genres/blues/blues.00087.au
# /home/akshat/signals/dataset/genres/blues/blues.00017.au
# /home/akshat/signals/dataset/genres/blues/blues.00035.au
# /home/akshat/signals/dataset/genres/blues/blues.00010.au
# /home/akshat/signals/dataset/genres/blues/blues.00000.au
# /home/akshat/signals/dataset/genres/blues/blues.00081.au
# /home/akshat/signals/dataset/genres/blues/blues.00064.au
# /home/akshat/signals/dataset/genres/blues/blues.00021.au
# /home/akshat/signals/dataset/genres/blues/blues.00078.au
# /home/akshat/signals/dataset/genres/blues/blues.00052.au
# /home/akshat/signals/dataset/genres/blues/blues.00088.au
# /home/akshat/signals/dataset/genres/blues/blues.00034.au
# /home/akshat/signals/dataset/genres/blues/blues.00061.au
# /home/akshat/signals/dataset/genres/blues/blues.00098.au
# /home/akshat/signals/dataset/genres/blues/blues.00083.au
# /home/akshat/signals/dataset/genres/blues/blues.00013.au
# /home/akshat/signals/dataset/genres/blues/blues.00014.au
# /home/akshat/signals/dataset/genres/blues/blues.00091.au
# /home/akshat/signals/dataset/genres/blues/blues.00016.au
# /home/akshat/signals/dataset/genres/classical/classical.00027.au
# /home/akshat/signals/dataset/genres/classical/classical.00055.au
# /home/akshat/signals/dataset/genres/classical/classical.00096.au
# /home/akshat/signals/dataset/genres/classical/classical.00022.au
# /home/akshat/signals/dataset/genres/classical/classical.00024.au
# /home/akshat/signals/dataset/genres/classical/classical.00010.au
# /home/akshat/signals/dataset/genres/classical/classical.00093.au
# /home/akshat/signals/dataset/genres/classical/classical.00011.au
# /home/akshat/signals/dataset/genres/classical/classical.00053.au
# /home/akshat/signals/dataset/genres/classical/classical.00061.au
# /home/akshat/signals/dataset/genres/classical/classical.00060.au
# /home/akshat/signals/dataset/genres/classical/classical.00067.au
# /home/akshat/signals/dataset/genres/classical/classical.00031.au
# /home/akshat/signals/dataset/genres/classical/classical.00039.au
# /home/akshat/signals/dataset/genres/classical/classical.00025.au
# /home/akshat/signals/dataset/genres/classical/classical.00099.au
# /home/akshat/signals/dataset/genres/classical/classical.00068.au
# /home/akshat/signals/dataset/genres/classical/classical.00054.au
# /home/akshat/signals/dataset/genres/classical/classical.00081.au
# /home/akshat/signals/dataset/genres/classical/classical.00001.au
# /home/akshat/signals/dataset/genres/classical/classical.00066.au
# /home/akshat/signals/dataset/genres/classical/classical.00084.au
# /home/akshat/signals/dataset/genres/classical/classical.00000.au
# /home/akshat/signals/dataset/genres/classical/classical.00017.au
# /home/akshat/signals/dataset/genres/classical/classical.00036.au
# /home/akshat/signals/dataset/genres/classical/classical.00019.au
# /home/akshat/signals/dataset/genres/classical/classical.00058.au
# /home/akshat/signals/dataset/genres/classical/classical.00098.au
# /home/akshat/signals/dataset/genres/classical/classical.00083.au
# /home/akshat/signals/dataset/genres/classical/classical.00015.au
# /home/akshat/signals/dataset/genres/classical/classical.00012.au
# /home/akshat/signals/dataset/genres/classical/classical.00005.au
# /home/akshat/signals/dataset/genres/classical/classical.00065.au
# /home/akshat/signals/dataset/genres/classical/classical.00072.au
# /home/akshat/signals/dataset/genres/classical/classical.00085.au
# /home/akshat/signals/dataset/genres/classical/classical.00064.au
# /home/akshat/signals/dataset/genres/classical/classical.00062.au
# /home/akshat/signals/dataset/genres/classical/classical.00087.au
# /home/akshat/signals/dataset/genres/classical/classical.00028.au
# /home/akshat/signals/dataset/genres/classical/classical.00073.au
# /home/akshat/signals/dataset/genres/classical/classical.00070.au
# /home/akshat/signals/dataset/genres/classical/classical.00074.au
# /home/akshat/signals/dataset/genres/classical/classical.00020.au
# /home/akshat/signals/dataset/genres/classical/classical.00052.au
# /home/akshat/signals/dataset/genres/classical/classical.00002.au
# /home/akshat/signals/dataset/genres/classical/classical.00056.au
# /home/akshat/signals/dataset/genres/classical/classical.00057.au
# /home/akshat/signals/dataset/genres/classical/classical.00094.au
# /home/akshat/signals/dataset/genres/classical/classical.00009.au
# /home/akshat/signals/dataset/genres/classical/classical.00086.au
# /home/akshat/signals/dataset/genres/classical/classical.00023.au
# /home/akshat/signals/dataset/genres/classical/classical.00080.au
# /home/akshat/signals/dataset/genres/classical/classical.00089.au
# /home/akshat/signals/dataset/genres/classical/classical.00049.au
# /home/akshat/signals/dataset/genres/classical/classical.00032.au
# /home/akshat/signals/dataset/genres/classical/classical.00040.au
# /home/akshat/signals/dataset/genres/classical/classical.00069.au
# /home/akshat/signals/dataset/genres/classical/classical.00046.au
# /home/akshat/signals/dataset/genres/classical/classical.00078.au
# /home/akshat/signals/dataset/genres/classical/classical.00091.au
# /home/akshat/signals/dataset/genres/classical/classical.00029.au
# /home/akshat/signals/dataset/genres/classical/classical.00045.au
# /home/akshat/signals/dataset/genres/classical/classical.00047.au
# /home/akshat/signals/dataset/genres/classical/classical.00048.au
# /home/akshat/signals/dataset/genres/classical/classical.00004.au
# /home/akshat/signals/dataset/genres/classical/classical.00034.au
# /home/akshat/signals/dataset/genres/classical/classical.00033.au
# /home/akshat/signals/dataset/genres/classical/classical.00021.au
# /home/akshat/signals/dataset/genres/classical/classical.00076.au
# /home/akshat/signals/dataset/genres/classical/classical.00090.au
# /home/akshat/signals/dataset/genres/classical/classical.00071.au
# /home/akshat/signals/dataset/genres/classical/classical.00007.au
# /home/akshat/signals/dataset/genres/classical/classical.00008.au
# /home/akshat/signals/dataset/genres/classical/classical.00014.au
# /home/akshat/signals/dataset/genres/classical/classical.00030.au
# /home/akshat/signals/dataset/genres/classical/classical.00092.au
# /home/akshat/signals/dataset/genres/classical/classical.00042.au
# /home/akshat/signals/dataset/genres/classical/classical.00041.au
# /home/akshat/signals/dataset/genres/classical/classical.00075.au
# /home/akshat/signals/dataset/genres/classical/classical.00035.au
# /home/akshat/signals/dataset/genres/classical/classical.00003.au
# /home/akshat/signals/dataset/genres/classical/classical.00095.au
# /home/akshat/signals/dataset/genres/classical/classical.00006.au
# /home/akshat/signals/dataset/genres/classical/classical.00088.au
# /home/akshat/signals/dataset/genres/classical/classical.00097.au
# /home/akshat/signals/dataset/genres/classical/classical.00079.au
# /home/akshat/signals/dataset/genres/classical/classical.00016.au
# /home/akshat/signals/dataset/genres/classical/classical.00043.au
# /home/akshat/signals/dataset/genres/classical/classical.00026.au
# /home/akshat/signals/dataset/genres/classical/classical.00018.au
# /home/akshat/signals/dataset/genres/classical/classical.00077.au
# /home/akshat/signals/dataset/genres/classical/classical.00051.au
# /home/akshat/signals/dataset/genres/classical/classical.00050.au
# /home/akshat/signals/dataset/genres/classical/classical.00044.au
# /home/akshat/signals/dataset/genres/classical/classical.00038.au
# /home/akshat/signals/dataset/genres/classical/classical.00037.au
# /home/akshat/signals/dataset/genres/classical/classical.00013.au
# /home/akshat/signals/dataset/genres/classical/classical.00082.au
# /home/akshat/signals/dataset/genres/classical/classical.00063.au
# /home/akshat/signals/dataset/genres/classical/classical.00059.au
# /home/akshat/signals/dataset/genres/country/country.00025.au
# /home/akshat/signals/dataset/genres/country/country.00044.au
# /home/akshat/signals/dataset/genres/country/country.00082.au
# /home/akshat/signals/dataset/genres/country/country.00072.au
# /home/akshat/signals/dataset/genres/country/country.00002.au
# /home/akshat/signals/dataset/genres/country/country.00084.au
# /home/akshat/signals/dataset/genres/country/country.00079.au
# /home/akshat/signals/dataset/genres/country/country.00027.au
# /home/akshat/signals/dataset/genres/country/country.00056.au
# /home/akshat/signals/dataset/genres/country/country.00061.au
# /home/akshat/signals/dataset/genres/country/country.00053.au
# /home/akshat/signals/dataset/genres/country/country.00080.au
# /home/akshat/signals/dataset/genres/country/country.00064.au
# /home/akshat/signals/dataset/genres/country/country.00022.au
# /home/akshat/signals/dataset/genres/country/country.00062.au
# /home/akshat/signals/dataset/genres/country/country.00049.au
# /home/akshat/signals/dataset/genres/country/country.00042.au
# /home/akshat/signals/dataset/genres/country/country.00010.au
# /home/akshat/signals/dataset/genres/country/country.00036.au
# /home/akshat/signals/dataset/genres/country/country.00020.au
# /home/akshat/signals/dataset/genres/country/country.00069.au
# /home/akshat/signals/dataset/genres/country/country.00032.au
# /home/akshat/signals/dataset/genres/country/country.00052.au
# /home/akshat/signals/dataset/genres/country/country.00011.au
# /home/akshat/signals/dataset/genres/country/country.00089.au
# /home/akshat/signals/dataset/genres/country/country.00074.au
# /home/akshat/signals/dataset/genres/country/country.00090.au
# /home/akshat/signals/dataset/genres/country/country.00008.au
# /home/akshat/signals/dataset/genres/country/country.00028.au
# /home/akshat/signals/dataset/genres/country/country.00001.au
# /home/akshat/signals/dataset/genres/country/country.00047.au
# /home/akshat/signals/dataset/genres/country/country.00009.au
# /home/akshat/signals/dataset/genres/country/country.00043.au
# /home/akshat/signals/dataset/genres/country/country.00019.au
# /home/akshat/signals/dataset/genres/country/country.00058.au
# /home/akshat/signals/dataset/genres/country/country.00077.au
# /home/akshat/signals/dataset/genres/country/country.00073.au
# /home/akshat/signals/dataset/genres/country/country.00023.au
# /home/akshat/signals/dataset/genres/country/country.00076.au
# /home/akshat/signals/dataset/genres/country/country.00038.au
# /home/akshat/signals/dataset/genres/country/country.00078.au
# /home/akshat/signals/dataset/genres/country/country.00094.au
# /home/akshat/signals/dataset/genres/country/country.00066.au
# /home/akshat/signals/dataset/genres/country/country.00041.au
# /home/akshat/signals/dataset/genres/country/country.00016.au
# /home/akshat/signals/dataset/genres/country/country.00005.au
# /home/akshat/signals/dataset/genres/country/country.00040.au
# /home/akshat/signals/dataset/genres/country/country.00015.au
# /home/akshat/signals/dataset/genres/country/country.00051.au
# /home/akshat/signals/dataset/genres/country/country.00031.au
# /home/akshat/signals/dataset/genres/country/country.00045.au
# /home/akshat/signals/dataset/genres/country/country.00087.au
# /home/akshat/signals/dataset/genres/country/country.00093.au
# /home/akshat/signals/dataset/genres/country/country.00092.au
# /home/akshat/signals/dataset/genres/country/country.00099.au
# /home/akshat/signals/dataset/genres/country/country.00055.au
# /home/akshat/signals/dataset/genres/country/country.00070.au
# /home/akshat/signals/dataset/genres/country/country.00086.au
# /home/akshat/signals/dataset/genres/country/country.00071.au
# /home/akshat/signals/dataset/genres/country/country.00029.au
# /home/akshat/signals/dataset/genres/country/country.00057.au
# /home/akshat/signals/dataset/genres/country/country.00026.au
# /home/akshat/signals/dataset/genres/country/country.00068.au
# /home/akshat/signals/dataset/genres/country/country.00081.au
# /home/akshat/signals/dataset/genres/country/country.00075.au
# /home/akshat/signals/dataset/genres/country/country.00000.au
# /home/akshat/signals/dataset/genres/country/country.00065.au
# /home/akshat/signals/dataset/genres/country/country.00021.au
# /home/akshat/signals/dataset/genres/country/country.00097.au
# /home/akshat/signals/dataset/genres/country/country.00034.au
# /home/akshat/signals/dataset/genres/country/country.00095.au
# /home/akshat/signals/dataset/genres/country/country.00024.au
# /home/akshat/signals/dataset/genres/country/country.00018.au
# /home/akshat/signals/dataset/genres/country/country.00054.au
# /home/akshat/signals/dataset/genres/country/country.00050.au
# /home/akshat/signals/dataset/genres/country/country.00035.au
# /home/akshat/signals/dataset/genres/country/country.00033.au
# /home/akshat/signals/dataset/genres/country/country.00030.au
# /home/akshat/signals/dataset/genres/country/country.00003.au
# /home/akshat/signals/dataset/genres/country/country.00067.au
# /home/akshat/signals/dataset/genres/country/country.00006.au
# /home/akshat/signals/dataset/genres/country/country.00088.au
# /home/akshat/signals/dataset/genres/country/country.00060.au
# /home/akshat/signals/dataset/genres/country/country.00048.au
# /home/akshat/signals/dataset/genres/country/country.00037.au
# /home/akshat/signals/dataset/genres/country/country.00017.au
# /home/akshat/signals/dataset/genres/country/country.00012.au
# /home/akshat/signals/dataset/genres/country/country.00085.au
# /home/akshat/signals/dataset/genres/country/country.00013.au
# /home/akshat/signals/dataset/genres/country/country.00063.au
# /home/akshat/signals/dataset/genres/country/country.00004.au
# /home/akshat/signals/dataset/genres/country/country.00059.au
# /home/akshat/signals/dataset/genres/country/country.00007.au
# /home/akshat/signals/dataset/genres/country/country.00091.au
# /home/akshat/signals/dataset/genres/country/country.00014.au
# /home/akshat/signals/dataset/genres/country/country.00096.au
# /home/akshat/signals/dataset/genres/country/country.00098.au
# /home/akshat/signals/dataset/genres/country/country.00046.au
# /home/akshat/signals/dataset/genres/country/country.00039.au
# /home/akshat/signals/dataset/genres/country/country.00083.au
# /home/akshat/signals/dataset/genres/rock/rock.00031.au
# /home/akshat/signals/dataset/genres/rock/rock.00008.au
# /home/akshat/signals/dataset/genres/rock/rock.00024.au
# /home/akshat/signals/dataset/genres/rock/rock.00012.au
# /home/akshat/signals/dataset/genres/rock/rock.00026.au
# /home/akshat/signals/dataset/genres/rock/rock.00036.au
# /home/akshat/signals/dataset/genres/rock/rock.00056.au
# /home/akshat/signals/dataset/genres/rock/rock.00037.au
# /home/akshat/signals/dataset/genres/rock/rock.00074.au
# /home/akshat/signals/dataset/genres/rock/rock.00059.au
# /home/akshat/signals/dataset/genres/rock/rock.00046.au
# /home/akshat/signals/dataset/genres/rock/rock.00003.au
# /home/akshat/signals/dataset/genres/rock/rock.00070.au
# /home/akshat/signals/dataset/genres/rock/rock.00067.au
# /home/akshat/signals/dataset/genres/rock/rock.00051.au
# /home/akshat/signals/dataset/genres/rock/rock.00060.au
# /home/akshat/signals/dataset/genres/rock/rock.00044.au
# /home/akshat/signals/dataset/genres/rock/rock.00066.au
# /home/akshat/signals/dataset/genres/rock/rock.00029.au
# /home/akshat/signals/dataset/genres/rock/rock.00053.au
# /home/akshat/signals/dataset/genres/rock/rock.00095.au
# /home/akshat/signals/dataset/genres/rock/rock.00009.au
# /home/akshat/signals/dataset/genres/rock/rock.00039.au
# /home/akshat/signals/dataset/genres/rock/rock.00083.au
# /home/akshat/signals/dataset/genres/rock/rock.00042.au
# /home/akshat/signals/dataset/genres/rock/rock.00091.au
# /home/akshat/signals/dataset/genres/rock/rock.00028.au
# /home/akshat/signals/dataset/genres/rock/rock.00032.au
# /home/akshat/signals/dataset/genres/rock/rock.00085.au
# /home/akshat/signals/dataset/genres/rock/rock.00058.au
# /home/akshat/signals/dataset/genres/rock/rock.00002.au
# /home/akshat/signals/dataset/genres/rock/rock.00062.au
# /home/akshat/signals/dataset/genres/rock/rock.00007.au
# /home/akshat/signals/dataset/genres/rock/rock.00084.au
# /home/akshat/signals/dataset/genres/rock/rock.00025.au
# /home/akshat/signals/dataset/genres/rock/rock.00069.au
# /home/akshat/signals/dataset/genres/rock/rock.00021.au
# /home/akshat/signals/dataset/genres/rock/rock.00013.au
# /home/akshat/signals/dataset/genres/rock/rock.00014.au
# /home/akshat/signals/dataset/genres/rock/rock.00043.au
# /home/akshat/signals/dataset/genres/rock/rock.00092.au
# /home/akshat/signals/dataset/genres/rock/rock.00057.au
# /home/akshat/signals/dataset/genres/rock/rock.00068.au
# /home/akshat/signals/dataset/genres/rock/rock.00055.au
# /home/akshat/signals/dataset/genres/rock/rock.00047.au
# /home/akshat/signals/dataset/genres/rock/rock.00064.au
# /home/akshat/signals/dataset/genres/rock/rock.00040.au
# /home/akshat/signals/dataset/genres/rock/rock.00076.au
# /home/akshat/signals/dataset/genres/rock/rock.00041.au
# /home/akshat/signals/dataset/genres/rock/rock.00004.au
# /home/akshat/signals/dataset/genres/rock/rock.00096.au
# /home/akshat/signals/dataset/genres/rock/rock.00038.au
# /home/akshat/signals/dataset/genres/rock/rock.00030.au
# /home/akshat/signals/dataset/genres/rock/rock.00035.au
# /home/akshat/signals/dataset/genres/rock/rock.00071.au
# /home/akshat/signals/dataset/genres/rock/rock.00020.au
# /home/akshat/signals/dataset/genres/rock/rock.00001.au
# /home/akshat/signals/dataset/genres/rock/rock.00048.au
# /home/akshat/signals/dataset/genres/rock/rock.00086.au
# /home/akshat/signals/dataset/genres/rock/rock.00098.au
# /home/akshat/signals/dataset/genres/rock/rock.00052.au
# /home/akshat/signals/dataset/genres/rock/rock.00077.au
# /home/akshat/signals/dataset/genres/rock/rock.00016.au
# /home/akshat/signals/dataset/genres/rock/rock.00034.au
# /home/akshat/signals/dataset/genres/rock/rock.00089.au
# /home/akshat/signals/dataset/genres/rock/rock.00019.au
# /home/akshat/signals/dataset/genres/rock/rock.00090.au
# /home/akshat/signals/dataset/genres/rock/rock.00045.au
# /home/akshat/signals/dataset/genres/rock/rock.00072.au
# /home/akshat/signals/dataset/genres/rock/rock.00027.au
# /home/akshat/signals/dataset/genres/rock/rock.00081.au
# /home/akshat/signals/dataset/genres/rock/rock.00049.au
# /home/akshat/signals/dataset/genres/rock/rock.00061.au
# /home/akshat/signals/dataset/genres/rock/rock.00015.au
# /home/akshat/signals/dataset/genres/rock/rock.00073.au
# /home/akshat/signals/dataset/genres/rock/rock.00023.au
# /home/akshat/signals/dataset/genres/rock/rock.00022.au
# /home/akshat/signals/dataset/genres/rock/rock.00075.au
# /home/akshat/signals/dataset/genres/rock/rock.00000.au
# /home/akshat/signals/dataset/genres/rock/rock.00093.au
# /home/akshat/signals/dataset/genres/rock/rock.00079.au
# /home/akshat/signals/dataset/genres/rock/rock.00094.au
# /home/akshat/signals/dataset/genres/rock/rock.00088.au
# /home/akshat/signals/dataset/genres/rock/rock.00080.au
# /home/akshat/signals/dataset/genres/rock/rock.00054.au
# /home/akshat/signals/dataset/genres/rock/rock.00017.au
# /home/akshat/signals/dataset/genres/rock/rock.00005.au
# /home/akshat/signals/dataset/genres/rock/rock.00078.au
# /home/akshat/signals/dataset/genres/rock/rock.00099.au
# /home/akshat/signals/dataset/genres/rock/rock.00087.au
# /home/akshat/signals/dataset/genres/rock/rock.00018.au
# /home/akshat/signals/dataset/genres/rock/rock.00063.au
# /home/akshat/signals/dataset/genres/rock/rock.00065.au
# /home/akshat/signals/dataset/genres/rock/rock.00097.au
# /home/akshat/signals/dataset/genres/rock/rock.00006.au
# /home/akshat/signals/dataset/genres/rock/rock.00033.au
# /home/akshat/signals/dataset/genres/rock/rock.00010.au
# /home/akshat/signals/dataset/genres/rock/rock.00011.au
# /home/akshat/signals/dataset/genres/rock/rock.00050.au
# /home/akshat/signals/dataset/genres/rock/rock.00082.au
# /home/akshat/signals/dataset/genres/disco/disco.00021.au
# /home/akshat/signals/dataset/genres/disco/disco.00026.au
# /home/akshat/signals/dataset/genres/disco/disco.00007.au
# /home/akshat/signals/dataset/genres/disco/disco.00094.au
# /home/akshat/signals/dataset/genres/disco/disco.00099.au
# /home/akshat/signals/dataset/genres/disco/disco.00070.au
# /home/akshat/signals/dataset/genres/disco/disco.00035.au
# /home/akshat/signals/dataset/genres/disco/disco.00052.au
# /home/akshat/signals/dataset/genres/disco/disco.00066.au
# /home/akshat/signals/dataset/genres/disco/disco.00050.au
# /home/akshat/signals/dataset/genres/disco/disco.00016.au
# /home/akshat/signals/dataset/genres/disco/disco.00098.au
# /home/akshat/signals/dataset/genres/disco/disco.00091.au
# /home/akshat/signals/dataset/genres/disco/disco.00038.au
# /home/akshat/signals/dataset/genres/disco/disco.00037.au
# /home/akshat/signals/dataset/genres/disco/disco.00065.au
# /home/akshat/signals/dataset/genres/disco/disco.00075.au
# /home/akshat/signals/dataset/genres/disco/disco.00073.au
# /home/akshat/signals/dataset/genres/disco/disco.00076.au
# /home/akshat/signals/dataset/genres/disco/disco.00039.au
# /home/akshat/signals/dataset/genres/disco/disco.00054.au
# /home/akshat/signals/dataset/genres/disco/disco.00031.au
# /home/akshat/signals/dataset/genres/disco/disco.00063.au
# /home/akshat/signals/dataset/genres/disco/disco.00045.au
# /home/akshat/signals/dataset/genres/disco/disco.00036.au
# /home/akshat/signals/dataset/genres/disco/disco.00011.au
# /home/akshat/signals/dataset/genres/disco/disco.00042.au
# /home/akshat/signals/dataset/genres/disco/disco.00004.au
# /home/akshat/signals/dataset/genres/disco/disco.00018.au
# /home/akshat/signals/dataset/genres/disco/disco.00079.au
# /home/akshat/signals/dataset/genres/disco/disco.00029.au
# /home/akshat/signals/dataset/genres/disco/disco.00084.au
# /home/akshat/signals/dataset/genres/disco/disco.00058.au
# /home/akshat/signals/dataset/genres/disco/disco.00034.au
# /home/akshat/signals/dataset/genres/disco/disco.00089.au
# /home/akshat/signals/dataset/genres/disco/disco.00092.au
# /home/akshat/signals/dataset/genres/disco/disco.00027.au
# /home/akshat/signals/dataset/genres/disco/disco.00051.au
# /home/akshat/signals/dataset/genres/disco/disco.00059.au
# /home/akshat/signals/dataset/genres/disco/disco.00005.au
# /home/akshat/signals/dataset/genres/disco/disco.00040.au
# /home/akshat/signals/dataset/genres/disco/disco.00096.au
# /home/akshat/signals/dataset/genres/disco/disco.00047.au
# /home/akshat/signals/dataset/genres/disco/disco.00068.au
# /home/akshat/signals/dataset/genres/disco/disco.00013.au
# /home/akshat/signals/dataset/genres/disco/disco.00097.au
# /home/akshat/signals/dataset/genres/disco/disco.00041.au
# /home/akshat/signals/dataset/genres/disco/disco.00032.au
# /home/akshat/signals/dataset/genres/disco/disco.00003.au
# /home/akshat/signals/dataset/genres/disco/disco.00072.au
# /home/akshat/signals/dataset/genres/disco/disco.00022.au
# /home/akshat/signals/dataset/genres/disco/disco.00095.au
# /home/akshat/signals/dataset/genres/disco/disco.00080.au
# /home/akshat/signals/dataset/genres/disco/disco.00086.au
# /home/akshat/signals/dataset/genres/disco/disco.00017.au
# /home/akshat/signals/dataset/genres/disco/disco.00020.au
# /home/akshat/signals/dataset/genres/disco/disco.00033.au
# /home/akshat/signals/dataset/genres/disco/disco.00012.au
# /home/akshat/signals/dataset/genres/disco/disco.00015.au
# /home/akshat/signals/dataset/genres/disco/disco.00067.au
# /home/akshat/signals/dataset/genres/disco/disco.00074.au
# /home/akshat/signals/dataset/genres/disco/disco.00043.au
# /home/akshat/signals/dataset/genres/disco/disco.00061.au
# /home/akshat/signals/dataset/genres/disco/disco.00048.au
# /home/akshat/signals/dataset/genres/disco/disco.00049.au
# /home/akshat/signals/dataset/genres/disco/disco.00069.au
# /home/akshat/signals/dataset/genres/disco/disco.00081.au
# /home/akshat/signals/dataset/genres/disco/disco.00087.au
# /home/akshat/signals/dataset/genres/disco/disco.00028.au
# /home/akshat/signals/dataset/genres/disco/disco.00064.au
# /home/akshat/signals/dataset/genres/disco/disco.00078.au
# /home/akshat/signals/dataset/genres/disco/disco.00057.au
# /home/akshat/signals/dataset/genres/disco/disco.00093.au
# /home/akshat/signals/dataset/genres/disco/disco.00044.au
# /home/akshat/signals/dataset/genres/disco/disco.00000.au
# /home/akshat/signals/dataset/genres/disco/disco.00083.au
# /home/akshat/signals/dataset/genres/disco/disco.00090.au
# /home/akshat/signals/dataset/genres/disco/disco.00030.au
# /home/akshat/signals/dataset/genres/disco/disco.00023.au
# /home/akshat/signals/dataset/genres/disco/disco.00056.au
# /home/akshat/signals/dataset/genres/disco/disco.00025.au
# /home/akshat/signals/dataset/genres/disco/disco.00001.au
# /home/akshat/signals/dataset/genres/disco/disco.00053.au
# /home/akshat/signals/dataset/genres/disco/disco.00006.au
# /home/akshat/signals/dataset/genres/disco/disco.00060.au
# /home/akshat/signals/dataset/genres/disco/disco.00010.au
# /home/akshat/signals/dataset/genres/disco/disco.00046.au
# /home/akshat/signals/dataset/genres/disco/disco.00019.au
# /home/akshat/signals/dataset/genres/disco/disco.00009.au
# /home/akshat/signals/dataset/genres/disco/disco.00002.au
# /home/akshat/signals/dataset/genres/disco/disco.00082.au
# /home/akshat/signals/dataset/genres/disco/disco.00085.au
# /home/akshat/signals/dataset/genres/disco/disco.00014.au
# /home/akshat/signals/dataset/genres/disco/disco.00062.au
# /home/akshat/signals/dataset/genres/disco/disco.00071.au
# /home/akshat/signals/dataset/genres/disco/disco.00055.au
# /home/akshat/signals/dataset/genres/disco/disco.00024.au
# /home/akshat/signals/dataset/genres/disco/disco.00077.au
# /home/akshat/signals/dataset/genres/disco/disco.00088.au
# /home/akshat/signals/dataset/genres/disco/disco.00008.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00081.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00072.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00042.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00006.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00088.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00092.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00057.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00083.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00014.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00045.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00041.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00003.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00063.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00054.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00046.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00058.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00076.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00080.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00099.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00028.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00094.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00038.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00036.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00084.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00065.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00004.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00010.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00016.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00021.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00086.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00060.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00061.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00027.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00079.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00096.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00002.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00097.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00073.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00007.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00082.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00008.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00085.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00051.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00075.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00001.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00064.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00078.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00062.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00053.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00039.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00090.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00018.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00050.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00043.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00059.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00044.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00031.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00052.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00017.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00023.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00048.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00011.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00012.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00049.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00089.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00095.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00029.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00034.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00091.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00009.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00055.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00074.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00013.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00077.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00071.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00066.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00070.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00030.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00067.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00000.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00035.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00024.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00047.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00093.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00026.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00015.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00020.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00087.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00056.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00005.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00040.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00025.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00068.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00022.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00098.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00019.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00032.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00033.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00069.au
# /home/akshat/signals/dataset/genres/reggae/reggae.00037.au

# %%
spectrogram = load_song('./rock/rock.00000.au', 8000)
mel_spectrogram = mel_spectrogram_func(spectrogram)
peaks = get_peaks(mel_spectrogram)
#                 show_peaks(peaks)
#                 max_amplitude_each_frame(mel_spectrogram)
eh = generate_eh(peaks)
ev = generate_ev(peaks)
ec = generate_ec(peaks)
em = generate_em(peaks)
#                 eh_t = lle(eh, 6, 3)
#                 ev_t = lle(ev, 3, 3)
#                 ec_t = lle(ec, 3, 3)
#                 em_t = lle(em, 6, 3)
fingerprint = generate_fingerprint(eh, ev, ec, em)
min_dist = float('inf')
match = ""

for x in fingerprints.keys():
    f = fingerprints[x]
#     print(x)
    distance, path = fastdtw(f, fingerprint)
#     print(distance)
    if (distance < min_dist):
        min_dist = distance
        match = x
print(match)
